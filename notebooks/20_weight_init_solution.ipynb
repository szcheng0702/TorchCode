# %% [markdown]
# # Solution: Kaiming Initialization
#
# Reference solution.

# %%
import torch
import math

# %%
# ✅ SOLUTION

def kaiming_init(weight):
    fan_in = weight.shape[1] if weight.dim() >= 2 else weight.shape[0]
    std = math.sqrt(2.0 / fan_in)
    with torch.no_grad():
        weight.normal_(0, std)
    return weight

# %%
# Demo
import math
w = torch.empty(256, 512)
kaiming_init(w)
print(f'Mean: {w.mean():.4f} (expect ~0)')
print(f'Std:  {w.std():.4f} (expect {math.sqrt(2/512):.4f})')
# Out:
# Mean: -0.0001 (expect ~0)
# Std:  0.0624 (expect 0.0625)

# %%
from torch_judge import check
check('weight_init')
# Out:
# 🧪 Testing: Kaiming Initialization (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Mean approximately 0 (5.4ms)
#   ✅ [2/4] Std matches sqrt(2/fan_in) (12.5ms)
#   ✅ [3/4] Returns same tensor (in-place) (0.2ms)
#   ✅ [4/4] Smaller fan_in gives larger std (0.5ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (18.6ms total)
#   Progress saved. Run status() to see your dashboard.
